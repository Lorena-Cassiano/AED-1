# %% [markdown]
# Calculo da Area

# %%
base= float(input("Digite a base: "))
altura = float(input("Digite a altura: "))
area = base * altura
print("A area do quadrilatero é: ", area)
# Out:
# Digite a base:  4.7
# Digite a altura:  5.2
# A area do quadrilatero é:  24.44
