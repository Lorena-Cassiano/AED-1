# %% [markdown]
# # Lista de exercícios AED1 - Parte 1

# %% [markdown]
# ### Exercício 0 - Faça um algoritmo para ler um número e mostrar se ele é par ou impar, positivo ou negativo.

# %%
numero= int (input ("Insira o número desejado: "))
if numero %2 == 0:
    print ("O número é par") 
else:
    print ("O número é impar")

if numero > 0:
    print ("O número é positivo")
elif numero < 0:
    print ("O número é negativo")

else:
    print ("O número é zero")
# Out:
# Insira o número desejado:  83
# O número é impar
# O número é positivo

# %% [markdown]
# ### Exercício 1 - Faça um Programa que peça dois números e imprima o maior deles.

# %%
numero1 = float(input("Escreva um número: "))
numero2 = float(input("Escreva o segundo número"))

print("O maior número é: ", max(numero1, numero2))
# Out:
# Escreva um número:  44
# Escreva o segundo número 84
# O maior número é:  84.0

# %% [markdown]
# ### Exercício 2 - Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
numero = float(input("Escreva um número: "))

if numero > 0:
    print ("O número é positivo")
elif numero < 0:
    print ("O número é negativo")

else:
    print ("O número é zero")
# Out:
# Escreva um número:  0
# O número é zero

# %% [markdown]
# ### Exercício 3 - Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
letra = input("Escreva uma letra: ").lower()

if letra in ("a", "e", "i", "o", "u"):
    print ("Essa letra é uma vogal")

else: 
    print ("Essa letra é uma consoante")

# %% [markdown]
# ### Exercício 4 - Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# ##### a. A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### b. A mensagem "Reprovado", se a média for menor do que sete;
# ##### c. A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota1 = float(input("Insira valor da nota 1: "))
nota2 = float(input("Insira valor da nota 2: "))

media = (nota1 + nota2)/2

if media == 10:
     print (f'Média:{media}, APROVADO com DISTINÇÃO')

elif media >=7:
    print (f'Média:{media}, APROVADO')

else:
    print (f'Média:{media}, REPROVADO')
# Out:
# Insira valor da nota 1:  10
# Insira valor da nota 2:  10
# Média:10.0, APROVADO com DISTINÇÃO

# %% [markdown]
# ### Exercício 5 - Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
produto1= float(input("Insira o preço do produto 1: $ "))
produto2= float(input("Insira o preço do produto 2: $ "))
produto3= float(input("Insira o preço do produto 3: $ "))

print("O produto que deve comprar é o de: $ ", min(produto1, produto2, produto3))
# Out:
# Insira o preço do produto 1: $  12
# Insira o preço do produto 2: $  156
# Insira o preço do produto 3: $  1532
# O produto que deve comprar é o de: $  12.0

# %% [markdown]
# ### Exercício 6 - Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
n1 = float(input("Insira um número:"))
n2 = float(input("Insira um número:"))
n3 = float(input("Insira um número:"))

if n1 >= n2 and n1 >= n3:
    if n2 >= n3:
        print(n1, n2, n3)
    else:
        print(n1, n3, n2)
elif n2 >= n1 and n2 >= n3:
    if n1 >= n3:
        print(n2, n1, n3)
    else:
        print(n2, n3, n1)
else:
    if n1 >= n2:
        print(n3, n1, n2)
    else:
        print(n3, n2, n1)

# %% [markdown]
# ### Exercício 7 - Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno.
# Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
turno= input("Considerando M -Matutino; V-Vespertino ou N- Noturno. Qual turno você estuda?").upper()

if turno == ("M"):
    print("Bom Dia!")

elif turno == ("V"):
    print("Boa Tarde!")

elif turno == ("N"):
    print ("Boa Noite!")

else:
    print ("Valor Inválido!")
# Out:
# Considerando M -Matutino; V-Vespertino ou N- Noturno. Qual turno você estuda? n
# Boa Noite!

# %% [markdown]
# ### Exercício 8 - As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
# #### a. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no  salário atual:
#
# #### b. salários até R$ 280,00 (incluindo) : aumento de 20%
#
# #### c. salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#
# #### d. salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#
# #### e. salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# #### f. o salário antes do reajuste;
#
# #### g. o percentual de aumento aplicado;
#
# #### h. o valor do aumento;
#
# #### i. o novo salário, após o aumento.

# %%
salario = float(input("Insira seu salário:$ ")) 

if salario <= 280.00:
    print("Salário antes do reajuste:$ ", salario)
    print("Percentual de aumento: 20% ")
    print("Valor do aumento:$ ", salario*0.2)
    print("Salário após aumento:$ ", salario*0.2+salario)

elif salario>280 and salario < 700:
    print("Salário antes do reajuste:$ ", salario)
    print("Percentual de aumento: 15% ")
    print("Valor do aumento:$ ", salario*0.15)
    print("Salário após aumento:$ ", salario*0.15+salario)

elif salario>=700 and salario <1500:
    print("Salário antes do reajuste:$ ", salario)
    print("Percentual de aumento: 10% ")
    print("Valor do aumento:$ ", salario*0.1)
    print("Salário após aumento:$ ", salario*0.1+salario)

else:
    print("Salário antes do reajuste:$ ", salario)
    print("Percentual de aumento: 0.05% ")
    print("Valor do aumento:$ ", salario*0.05)
    print("Salário após aumento:$ ", salario*0.05+salario)
# Out:
# Insira seu salário:$  101
# Salário antes do reajuste:$  101.0
# Percentual de aumento: 20%
# Valor do aumento:$  20.200000000000003
# Salário após aumento:$  121.2

# %% [markdown]
# ### Exercício 9 - Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.

# %% [markdown]
# ##### a. Desconto do IR:
#
# ##### b. Salário Bruto até 900 (inclusive) - isento
#
# ##### c. Salário Bruto até 1500 (inclusive) - desconto de 5%
#
# ##### d. Salário Bruto até 2500 (inclusive) - desconto de 10%
#
# ##### e. Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo
#
# ##### abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220

# %%
salario= float(input("Insira o valor da sua hora de trabalho:$ ")) #Esse ficou mais ajeitado rsrs
hora= float(input("Insira a quantidade de horas trabalhadas no mês: "))

salarioh= salario*hora

if salarioh <= 900:
    print ("Isento de impostos")
    ir = 0

elif salarioh <= 1500:
    ir = 0.05

elif salarioh <= 2500:
    ir = 0.1

else:
    ir = 0.2

deducoes= (ir*salarioh)+(salarioh*0.03)

print ("-" * 50)
print ("Salário bruto:$ ", salarioh)
print ("-" * 50)
print (f"IR:{ir}% ")
print ("FGTS (11%):$ ", salarioh*0.11)
print(f"Sindicato (3%): $ {salarioh*0.03:.2f}")
print ("-" * 50)
print(f"Total de deduções: $ {deducoes:.2f}")
print ("-" * 50)
print ("Salário Líquido:$ ", (salarioh - deducoes))
# Out:
# Insira o valor da sua hora de trabalho:$  25
# Insira a quantidade de horas trabalhadas no mês:  180
# --------------------------------------------------
# Salário bruto:$  4500.0
# --------------------------------------------------
# IR:0.2%
# FGTS (11%):$  495.0
# Sindicato (3%): $ 135.00
# --------------------------------------------------
# Total de deduções: $ 1035.00
# --------------------------------------------------
# Salário Líquido:$  3465.0

# %% [markdown]
# ### 10 - Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule
# a sua média. A atribuição de conceitos obedece à tabela abaixo:

# %% [markdown]
# ##### a.   Média de Aproveitamento  Conceito
#
# ##### b.   Entre 9.0 e 10.0        A
#
# ##### c.   Entre 7.5 e 9.0         B
#
# ##### d.   Entre 6.0 e 7.5         C
#
# ##### e.   Entre 4.0 e 6.0         D
#
# ##### f.   Entre 4.0 e zero        E

# %%
nota1 = float(input("Nota 1: "))
nota2 = float(input("Nota 2: "))

media= (nota1+nota2)/2

if media <= 4:
    print("E")

elif media <= 6:
    print("D")

elif media <= 7.5:
    print("C")

elif media <= 9:
    print("B")

else:
    print("A")
# Out:
# Nota 1:  10
# Nota 2:  2
# D
