# %%
#Faça um Programa que peça dois números e imprima o maior deles.

numero1 = float(input("Insira um numero: "))
numero2 = float(input("Insira o segundo numero: "))

if numero1 > numero2:
    print("O maior número é: ", numero1)

elif numero2 > numero1:
    print ("O maior número é: ", numero2)

else:
    print("Número 1 e 2 são iguais")
# Out:
# Insira um numero:  14
# Insira o segundo numero:  77
# O maior número é:  77.0

# %%
#Usando a função de máximo e mínimo:

numero1 = float(input("Insira um numero: "))
numero2 = float(input("Insira o segundo numero: "))

print("O maior número é: ", max(numero1, numero2))
# Out:
# Insira um numero:  -36
# Insira o segundo numero:  -44
# O maior número é:  -36.0

# %%
#Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

letra = input("Digite uma letra: ").lower() 

if letra in ["a", "e", "i", "o", "u"]:
    print("Essa letra é uma vogal")

else:
    print("Essa letra é uma consoante")
# Out:
# Digite uma letra:  ~
# Essa letra é uma consoante
